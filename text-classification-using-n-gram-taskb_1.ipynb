# %%
import pandas as pd
import numpy as np
import re
import warnings
import matplotlib
import matplotlib.pyplot as plt
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
import os

# %%
pd.set_option('display.max_colwidth', 255)
df_train =pd.read_csv('Urdu-threat-detection-FIRE2022/Train_Clean.csv')
df_test=pd.read_csv('Urdu-threat-detection-FIRE2022/Test_Clean.csv')
df_train
# Out:
#                                                                                                           Tweets  \
# 0                                                                                                      بکواس مت
# 1                                                                 تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                غدار منافق میر اللہ تمہیں زلیل
# 4     اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                          ...
# 3559                                                                            ارے شعر حقیقت میں پیچھے نا پڑنا
# 3560                            ہندوستانی باوردی غنڈا ایل او سی پتھر مار چیک کر رہا تھا پاکستانی فوجی جاگ یا سو
# 3561                                                                                           خبر افسوس ناک ھے
# 3562                   جناب محترم سلمان وفادارصاھب کیا پارلیمنٹ آئینی ادارہ نہیں جس اینٹ سے اینٹ بجانے والا شخص
# 3563                                                                          قد لڑکی شہد مکھی دونوں بہت خطرناک
#
#       label  S/G  word_count  char_count  word_density
# 0         1    1           2           7      0.250000
# 1         1    0           9          37      0.236842
# 2         1    1          11          52      0.207547
# 3         1    1           6          25      0.230769
# 4         1    0          23          83      0.273810
# ...     ...  ...         ...         ...           ...
# 3559      0    2           7          25      0.269231
# 3560      0    2          17          63      0.265625
# 3561      0    2           4          13      0.285714
# 3562      0    2          16          73      0.216216
# 3563      0    2           7          27      0.250000
#
# [3564 rows x 6 columns]

# %%
df_test
# Out:
#                                                                                                                                                                                                                         Tweet  \
# 0                                                                                                                          وزیراعل پنجاب کا ضلع راولپنڈی کا دورہ لینڈسلائیڈنگ متاثرین سے سمری طلب ہوٹل انڈسٹری پیکج کا اعلان
# 1    الحمدللہ پورے پاکستان وکلاء برادری کا کہنا ہم ضامن مراثی خلاف فری میں کیس لڑیں میں ان تمام وکلاء کا بہت شکر گزار اللہ تعالی آپ کا حامی وناصر آپ اس جر کو سلام دشمن اصحاب رسول تیری اب خیر نہیں معاویہ کوگرفتارکرو پرلعن
# 2                                                                                                                                                             جنوری مہلت ختم الٹی گنتی شروع ن لیگ خلاف بڑی کارروائی کا فیصلہ
# 3                          کروناکی آڑ میں حکومت اورفوج جوکھیل قادیانیوں کیلیےکھیل وہ ہرگز اس بھول میں مت رہیں وہ اس مقصد میں کامیاب ہم نے میں بھی شہادتیں بھی گردنیں حضور لیے ہوٸیں شہید یاان زندیقوں کو کاٹ دیں ان شاء اللہ
# 4                                                                                                                                                        حکومت ایکشن میں ورنہ اگر ہم ایکشن میں آگئے ہم کسی کوبھی نہیں چھوڑیں
# ..                                                                                                                                                                                                                        ...
# 930                                                                      کوئ پیڈ جیالوں کو بتا عمران احمد خان نیازی نام سے گالی کا ٹرینڈ کیا جواب میں ان کتوں شلواریں پینل ٹانگ دیں اس بات میں کسی کو کوئ شک نہیں ہونا چاہیے
# 931                                          مجبور نہ قانون ہاتھ میں دین اسلام خلاف بھی قانون گا اس کو میں جوتے نوک رکھتا زندگی لاکھ بھی دین قربان کر بھی دل نا بھرتا ہماری پاک آرمی ایسے کو کنٹرول جو دین اسلام خلاف کام کر
# 932                                                                                                                                                                                   ڈرامہ سیاست زلیل گہٹیا غلطی نہیں مانیں
# 933                                                                                                                                                   وزیراعظم صاحب آپ کا اتنی جلد بازی کا فیصلہ آپ جہالت کا م نہ بولتا ثبوت
# 934                                                                                                                                                                                    ہمارا ملک ہم جواب ملک دشمن تمہارے یار
#
#      Threat  G/S
# 0         0    2
# 1         1    1
# 2         1    1
# 3         1    1
# 4         1    1
# ..      ...  ...
# 930       1    1
# 931       1    1
# 932       0    2
# 933       0    2
# 934       0    2
#
# [935 rows x 3 columns]

# %%
#dropping the column word_count ,char_count and word_density
df_train_copy=df_train.copy()
df_train_copy.drop(["word_count","char_count","word_density"],axis=1,inplace=True)
df_train_copy
# Out:
#                                                                                                           Tweets  \
# 0                                                                                                      بکواس مت
# 1                                                                 تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                غدار منافق میر اللہ تمہیں زلیل
# 4     اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                          ...
# 3559                                                                            ارے شعر حقیقت میں پیچھے نا پڑنا
# 3560                            ہندوستانی باوردی غنڈا ایل او سی پتھر مار چیک کر رہا تھا پاکستانی فوجی جاگ یا سو
# 3561                                                                                           خبر افسوس ناک ھے
# 3562                   جناب محترم سلمان وفادارصاھب کیا پارلیمنٹ آئینی ادارہ نہیں جس اینٹ سے اینٹ بجانے والا شخص
# 3563                                                                          قد لڑکی شہد مکھی دونوں بہت خطرناک
#
#       label  S/G
# 0         1    1
# 1         1    0
# 2         1    1
# 3         1    1
# 4         1    0
# ...     ...  ...
# 3559      0    2
# 3560      0    2
# 3561      0    2
# 3562      0    2
# 3563      0    2
#
# [3564 rows x 3 columns]

# %%
df_train_copy.rename(columns={"Tweets":"Tweet","label":"Threat","S/G":"G/S"},inplace=True)
df_train_copy
# Out:
#                                                                                                            Tweet  \
# 0                                                                                                      بکواس مت
# 1                                                                 تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                غدار منافق میر اللہ تمہیں زلیل
# 4     اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                          ...
# 3559                                                                            ارے شعر حقیقت میں پیچھے نا پڑنا
# 3560                            ہندوستانی باوردی غنڈا ایل او سی پتھر مار چیک کر رہا تھا پاکستانی فوجی جاگ یا سو
# 3561                                                                                           خبر افسوس ناک ھے
# 3562                   جناب محترم سلمان وفادارصاھب کیا پارلیمنٹ آئینی ادارہ نہیں جس اینٹ سے اینٹ بجانے والا شخص
# 3563                                                                          قد لڑکی شہد مکھی دونوں بہت خطرناک
#
#       Threat  G/S
# 0          1    1
# 1          1    0
# 2          1    1
# 3          1    1
# 4          1    0
# ...      ...  ...
# 3559       0    2
# 3560       0    2
# 3561       0    2
# 3562       0    2
# 3563       0    2
#
# [3564 rows x 3 columns]

# %%
# to remove transcription rows that is empty
df_train_copy = df_train_copy[df_train_copy['Tweet'].notna()]
df_test=df_test[df_test["Tweet"].notna()]
df_train_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3564 entries, 0 to 3563
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   3564 non-null   object
#  1   Threat  3564 non-null   int64
#  2   G/S     3564 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 111.4+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 935 entries, 0 to 934
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   935 non-null    object
#  1   Threat  935 non-null    int64
#  2   G/S     935 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 29.2+ KB

# %% [markdown]
# After dropping the null values, there are no null values for the tweets attribute.

# %% [markdown]
# Data normalisation will be conducted for the trascription. One of the reasons is to convert the transcript into standard format, which important for data extraction later. In this data normalisation task, following task will be executed, which are:
# 1. Lowe Case
# 2. Removing punctuation and numbers
# 3. Tokenisation of the transcription
# 4. Lemmatisation
# 5. Remove Stop Words

# %%
df_train_copy.to_csv("Modified_Clean_train.csv")
df_train=pd.read_csv("Modified_Clean_train.csv",index_col=0)
df_train
# Out:
#                                                                                                            Tweet  \
# 0                                                                                                      بکواس مت
# 1                                                                 تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                غدار منافق میر اللہ تمہیں زلیل
# 4     اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                          ...
# 3559                                                                            ارے شعر حقیقت میں پیچھے نا پڑنا
# 3560                            ہندوستانی باوردی غنڈا ایل او سی پتھر مار چیک کر رہا تھا پاکستانی فوجی جاگ یا سو
# 3561                                                                                           خبر افسوس ناک ھے
# 3562                   جناب محترم سلمان وفادارصاھب کیا پارلیمنٹ آئینی ادارہ نہیں جس اینٹ سے اینٹ بجانے والا شخص
# 3563                                                                          قد لڑکی شہد مکھی دونوں بہت خطرناک
#
#       Threat  G/S
# 0          1    1
# 1          1    0
# 2          1    1
# 3          1    1
# 4          1    0
# ...      ...  ...
# 3559       0    2
# 3560       0    2
# 3561       0    2
# 3562       0    2
# 3563       0    2
#
# [3564 rows x 3 columns]

# %%
#concatinating the dataframes to and then we will slice them later for train and test data 
df=pd.concat([df_train,df_test],ignore_index=True)
df
# Out:
#                                                                                                                                                                                  Tweet  \
# 0                                                                                                                                                                            بکواس مت
# 1                                                                                                                                       تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                                                                                      آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                                                                                      غدار منافق میر اللہ تمہیں زلیل
# 4                                                                           اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                                                                                                ...
# 4494                              کوئ پیڈ جیالوں کو بتا عمران احمد خان نیازی نام سے گالی کا ٹرینڈ کیا جواب میں ان کتوں شلواریں پینل ٹانگ دیں اس بات میں کسی کو کوئ شک نہیں ہونا چاہیے
# 4495  مجبور نہ قانون ہاتھ میں دین اسلام خلاف بھی قانون گا اس کو میں جوتے نوک رکھتا زندگی لاکھ بھی دین قربان کر بھی دل نا بھرتا ہماری پاک آرمی ایسے کو کنٹرول جو دین اسلام خلاف کام کر
# 4496                                                                                                                                           ڈرامہ سیاست زلیل گہٹیا غلطی نہیں مانیں
# 4497                                                                                                           وزیراعظم صاحب آپ کا اتنی جلد بازی کا فیصلہ آپ جہالت کا م نہ بولتا ثبوت
# 4498                                                                                                                                            ہمارا ملک ہم جواب ملک دشمن تمہارے یار
#
#       Threat  G/S
# 0          1    1
# 1          1    0
# 2          1    1
# 3          1    1
# 4          1    0
# ...      ...  ...
# 4494       1    1
# 4495       1    1
# 4496       0    2
# 4497       0    2
# 4498       0    2
#
# [4499 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4499 entries, 0 to 4498
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweet   4499 non-null   object
#  1   Threat  4499 non-null   int64
#  2   G/S     4499 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 105.6+ KB

# %% [markdown]
# # <b>2.3 <span style='color:red'>|</span> Tokenisation </b> <a class="anchor" id="2.3"></a>

# %%
# to tokenise transcription

# import nltk
tk =WhitespaceTokenizer()
def tokenise(df, attribute):
    df['tokenised'] = df.apply(lambda row: tk.tokenize(str(row[attribute])), axis=1)
    return df
df=tokenise(df, 'Tweet')
df_experiment =df_train.copy()

# %%
display(df)
# Out:
#                                                                                                                                                                                  Tweet  \
# 0                                                                                                                                                                            بکواس مت
# 1                                                                                                                                       تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                                                                                      آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                                                                                      غدار منافق میر اللہ تمہیں زلیل
# 4                                                                           اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                                                                                                ...
# 4494                              کوئ پیڈ جیالوں کو بتا عمران احمد خان نیازی نام سے گالی کا ٹرینڈ کیا جواب میں ان کتوں شلواریں پینل ٹانگ دیں اس بات میں کسی کو کوئ شک نہیں ہونا چاہیے
# 4495  مجبور نہ قانون ہاتھ میں دین اسلام خلاف بھی قانون گا اس کو میں جوتے نوک رکھتا زندگی لاکھ بھی دین قربان کر بھی دل نا بھرتا ہماری پاک آرمی ایسے کو کنٹرول جو دین اسلام خلاف کام کر
# 4496                                                                                                                                           ڈرامہ سیاست زلیل گہٹیا غلطی نہیں مانیں
# 4497                                                                                                           وزیراعظم صاحب آپ کا اتنی جلد بازی کا فیصلہ آپ جہالت کا م نہ بولتا ثبوت
# 4498                                                                                                                                            ہمارا ملک ہم جواب ملک دشمن تمہارے یار
#
#       Threat  G/S  \
# 0          1    1
# 1          1    0
# 2          1    1
# 3          1    1
# 4          1    0
# ...      ...  ...
# 4494       1    1
# 4495       1    1
# 4496       0    2
# 4497       0    2
# 4498       0    2
#
#                                                                                                                                                                                                                     tokenised
# 0                                                                                                                                                                                                                 [بکواس, مت]
# 1                                                                                                                                                                     [تمہاری, ہیجڑا, فورس, نہتے, سامنے, بکری, بنی, ڈوب, مرو]
# 2                                                                                                                                                  [آفیسر, سمیتبھارتی, فوجی, جہنم, واصلبنکرز, تباہ, بھارت, کو, پتہ, لگ, جائے]
# 3                                                                                                                                                                                       [غدار, منافق, میر, اللہ, تمہیں, زلیل]
# 4                                                                                           [اگست, آپ, بھارت, کو, کیا, پیغام, دینا, چاہیں, میرا, پیغام, ھے, کشمیر, سے, نکل, جاو, ورنہ, کتے, موت, مارے, جاو, کشمیر, ہمارا, ھے]
# ...                                                                                                                                                                                                                       ...
# 4494                                    [کوئ, پیڈ, جیالوں, کو, بتا, عمران, احمد, خان, نیازی, نام, سے, گالی, کا, ٹرینڈ, کیا, جواب, میں, ان, کتوں, شلواریں, پینل, ٹانگ, دیں, اس, بات, میں, کسی, کو, کوئ, شک, نہیں, ہونا, چاہیے]
# 4495  [مجبور, نہ, قانون, ہاتھ, میں, دین, اسلام, خلاف, بھی, قانون, گا, اس, کو, میں, جوتے, نوک, رکھتا, زندگی, لاکھ, بھی, دین, قربان, کر, بھی, دل, نا, بھرتا, ہماری, پاک, آرمی, ایسے, کو, کنٹرول, جو, دین, اسلام, خلاف, کام, کر]
# 4496                                                                                                                                                                           [ڈرامہ, سیاست, زلیل, گہٹیا, غلطی, نہیں, مانیں]
# 4497                                                                                                                                  [وزیراعظم, صاحب, آپ, کا, اتنی, جلد, بازی, کا, فیصلہ, آپ, جہالت, کا, م, نہ, بولتا, ثبوت]
# 4498                                                                                                                                                                           [ہمارا, ملک, ہم, جواب, ملک, دشمن, تمہارے, یار]
#
# [4499 rows x 4 columns]

# %%
df["G/S"].unique()
# Out:
# array([1, 0, 2])

# %%
df["Threat"].unique()
# Out:
# array([1, 0])

# %%
df['stemmed_without_stop'] = df["tokenised"].apply(lambda x: ' '.join([word for word in x ]))

# %%
df
# Out:
#                                                                                                                                                                                  Tweet  \
# 0                                                                                                                                                                            بکواس مت
# 1                                                                                                                                       تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                                                                                      آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                                                                                      غدار منافق میر اللہ تمہیں زلیل
# 4                                                                           اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                                                                                                ...
# 4494                              کوئ پیڈ جیالوں کو بتا عمران احمد خان نیازی نام سے گالی کا ٹرینڈ کیا جواب میں ان کتوں شلواریں پینل ٹانگ دیں اس بات میں کسی کو کوئ شک نہیں ہونا چاہیے
# 4495  مجبور نہ قانون ہاتھ میں دین اسلام خلاف بھی قانون گا اس کو میں جوتے نوک رکھتا زندگی لاکھ بھی دین قربان کر بھی دل نا بھرتا ہماری پاک آرمی ایسے کو کنٹرول جو دین اسلام خلاف کام کر
# 4496                                                                                                                                           ڈرامہ سیاست زلیل گہٹیا غلطی نہیں مانیں
# 4497                                                                                                           وزیراعظم صاحب آپ کا اتنی جلد بازی کا فیصلہ آپ جہالت کا م نہ بولتا ثبوت
# 4498                                                                                                                                            ہمارا ملک ہم جواب ملک دشمن تمہارے یار
#
#       Threat  G/S  \
# 0          1    1
# 1          1    0
# 2          1    1
# 3          1    1
# 4          1    0
# ...      ...  ...
# 4494       1    1
# 4495       1    1
# 4496       0    2
# 4497       0    2
# 4498       0    2
#
#                                                                                                                                                                                                                     tokenised  \
# 0                                                                                                                                                                                                                 [بکواس, مت]
# 1                                                                                                                                                                     [تمہاری, ہیجڑا, فورس, نہتے, سامنے, بکری, بنی, ڈوب, مرو]
# 2                                                                                                                                                  [آفیسر, سمیتبھارتی, فوجی, جہنم, واصلبنکرز, تباہ, بھارت, کو, پتہ, لگ, جائے]
# 3                                                                                                                                                                                       [غدار, منافق, میر, اللہ, تمہیں, زلیل]
# 4                                                                                           [اگست, آپ, بھارت, کو, کیا, پیغام, دینا, چاہیں, میرا, پیغام, ھے, کشمیر, سے, نکل, جاو, ورنہ, کتے, موت, مارے, جاو, کشمیر, ہمارا, ھے]
# ...                                                                                                                                                                                                                       ...
# 4494                                    [کوئ, پیڈ, جیالوں, کو, بتا, عمران, احمد, خان, نیازی, نام, سے, گالی, کا, ٹرینڈ, کیا, جواب, میں, ان, کتوں, شلواریں, پینل, ٹانگ, دیں, اس, بات, میں, کسی, کو, کوئ, شک, نہیں, ہونا, چاہیے]
# 4495  [مجبور, نہ, قانون, ہاتھ, میں, دین, اسلام, خلاف, بھی, قانون, گا, اس, کو, میں, جوتے, نوک, رکھتا, زندگی, لاکھ, بھی, دین, قربان, کر, بھی, دل, نا, بھرتا, ہماری, پاک, آرمی, ایسے, کو, کنٹرول, جو, دین, اسلام, خلاف, کام, کر]
# 4496                                                                                                                                                                           [ڈرامہ, سیاست, زلیل, گہٹیا, غلطی, نہیں, مانیں]
# 4497                                                                                                                                  [وزیراعظم, صاحب, آپ, کا, اتنی, جلد, بازی, کا, فیصلہ, آپ, جہالت, کا, م, نہ, بولتا, ثبوت]
# 4498                                                                                                                                                                           [ہمارا, ملک, ہم, جواب, ملک, دشمن, تمہارے, یار]
#
#                                                                                                                                                                  stemmed_without_stop
# 0                                                                                                                                                                            بکواس مت
# 1                                                                                                                                       تمہاری ہیجڑا فورس نہتے سامنے بکری بنی ڈوب مرو
# 2                                                                                                                      آفیسر سمیتبھارتی فوجی جہنم واصلبنکرز تباہ بھارت کو پتہ لگ جائے
# 3                                                                                                                                                      غدار منافق میر اللہ تمہیں زلیل
# 4                                                                           اگست آپ بھارت کو کیا پیغام دینا چاہیں میرا پیغام ھے کشمیر سے نکل جاو ورنہ کتے موت مارے جاو کشمیر ہمارا ھے
# ...                                                                                                                                                                               ...
# 4494                              کوئ پیڈ جیالوں کو بتا عمران احمد خان نیازی نام سے گالی کا ٹرینڈ کیا جواب میں ان کتوں شلواریں پینل ٹانگ دیں اس بات میں کسی کو کوئ شک نہیں ہونا چاہیے
# 4495  مجبور نہ قانون ہاتھ میں دین اسلام خلاف بھی قانون گا اس کو میں جوتے نوک رکھتا زندگی لاکھ بھی دین قربان کر بھی دل نا بھرتا ہماری پاک آرمی ایسے کو کنٹرول جو دین اسلام خلاف کام کر
# 4496                                                                                                                                           ڈرامہ سیاست زلیل گہٹیا غلطی نہیں مانیں
# 4497                                                                                                           وزیراعظم صاحب آپ کا اتنی جلد بازی کا فیصلہ آپ جہالت کا م نہ بولتا ثبوت
# 4498                                                                                                                                            ہمارا ملک ہم جواب ملک دشمن تمہارے یار
#
# [4499 rows x 5 columns]

# %% [markdown]
# # <b>3.0 <span style='color:red'>|</span> Text N-Gram Feature Extraction </b> <a class="anchor" id="3.0"></a>

# %% [markdown]
# We will use sklearn class 'CountVectoriser' to extract different n-grams features. In order to do so, the transcription should be converted into a list format, rather than a dataframe. For the purpose of converting into a flat list (i.e., there is no inner list), the function of 'flat_list' that defined above is used.

# %%
# function to flatten one list
def flat_list(unflat_list):
    flatted = [item for sublist in unflat_list for item in sublist]
    return flatted

def to_list(df, attribute):
    # Select the normalised transcript column 
    df_transcription = df[[attribute]]
    # To convert the attribute into list format, but it has inner list. So it cannot put into the CountVectoriser
    unflat_list_transcription = df_transcription.values.tolist()
    # Let's use back the function defined above, "flat_list", to flatten the list
    flat_list_transcription = flat_list(unflat_list_transcription)
    return flat_list_transcription
flat_list_transcription = to_list(df ,'stemmed_without_stop')

# %% [markdown]
# # <b>3.1 <span style='color:red'>|</span> Extract 5 Types of N-Gram </b> <a class="anchor" id="3.1"></a>

# %% [markdown]
# CountVectorizer is used to convert a collection of transcript documents to a matrix of n-gram features. To explain the ngram_range, all values of n such such that min_n <= n <= max_n will be used. For example an ngram_range of (1, 1) means only unigrams, (1, 2) means unigrams and bigrams, and (2, 2) means only bigrams.

# %%
n_gram_features ={'unigram':(1,1),'unigram_bigram':(1,2),'bigram':(2,2),\
       'bigram_trigram':(2,3),'trigram':(3,3)}
feature_name=[]
temp=[]
for key, values in n_gram_features.items():
    temp.append(key)
    feature_name.append(key)
temp
# Out:
# ['unigram', 'unigram_bigram', 'bigram', 'bigram_trigram', 'trigram']

# %%
def generate_n_gram_features(flat_list_transcription):
    temp=[]
    for key, values in n_gram_features.items(): 
        vectorizer = CountVectorizer(ngram_range=values)
        vectorizer.fit(flat_list_transcription)
        temp.append(vectorizer.transform(flat_list_transcription))
    return temp
temp = generate_n_gram_features(flat_list_transcription)

# %% [markdown]
# # <b>3.2 <span style='color:red'>|</span> Dimension of Each Feature Vector </b> <a class="anchor" id="3.2"></a>

# %%
dataframes = {'unigram':temp[0], 
              'unigram_bigram':temp[1], 
              'bigram':temp[2], 
              'bigram_trigram':temp[3], 
              'trigram':temp[4]}
feature_vector= [] ; feature_vector_shape = []
for key in dataframes:
    feature_vector.append(key)
    feature_vector_shape.append(dataframes[key].shape)

n_gram_df = pd.DataFrame({'N-Gram Feature Vector':feature_vector, 'Data Dimension':feature_vector_shape})

# %%
n_gram_df
# Out:
#   N-Gram Feature Vector Data Dimension
# 0               unigram   (4499, 9045)
# 1        unigram_bigram  (4499, 48979)
# 2                bigram  (4499, 39934)
# 3        bigram_trigram  (4499, 88705)
# 4               trigram  (4499, 48771)

# %% [markdown]
# After the feature extraction process, 5 kinds of n-gram features are extracted. It is interesting to notice that when the number of 'n' getting higher (i.e, n=1:unigram, n=2:bigram, n=3:trigram), there is a higer number of columns. This is due to it is getting harder to find similar features that can be stored in similar column when it has a longer connected words as one featuer. If the feature is unique, it will automatically append additional column to store the feaure.

# %%
# to retrieve a unigram feature vector
dataframes['unigram']
# Out:
# <4499x9045 sparse matrix of type '<class 'numpy.int64'>'
# 	with 58117 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # <b>4.0 <span style='color:red'>|</span> Text Classification Modelling </b> <a class="anchor" id="4.0"></a>

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,roc_auc_score,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import warnings
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report

warnings.filterwarnings('ignore')
random_state_number =8888
df_target =df[['Threat']].values.ravel()
df_target
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
df_target.shape
# Out:
# (4499,)

# %%
metrics = {
    'f1':[f1_score, 'f1'], 
    "roc_auc":[roc_auc_score,"roc_auc"],
    "accuracy":[accuracy_score,"accuracy"]
}

# get evaluation result

def get_performance(param_grid, base_estimator, dataframes):
    df_name_list =[]; best_estimator_list=[]; best_score_list=[]; test_predict_result_list=[];
    metric_list = [];
    
    for df_name, df in dataframes.items():
        
        X_train, X_test, y_train, y_test =  df[:3564],df[3564:],df_target[:3564],df_target[3564:]#train_test_split(df, df_train["label"], test_size=0.2, random_state=random_state_number)
        for _, metric_dict in metrics.items():
            sh = HalvingGridSearchCV(base_estimator, param_grid, cv=5, scoring=metric_dict[1],random_state=random_state_number,
                                      factor=2).fit(X_train, y_train)

            best_estimator = sh.best_estimator_
            clf = best_estimator.fit(X_train, y_train)
            prediction = clf.predict(X_test)
#             test_predict_result = metric_dict[0](y_test, prediction, average='macro')#for multiclass
            test_predict_result = metric_dict[0](y_test, prediction)#for binary

            df_name_list.append(df_name) ; best_estimator_list.append(best_estimator) ; 
            best_score_list.append(sh.best_score_) ; 
            test_predict_result_list.append(test_predict_result) ;metric_list.append(metric_dict[1])
            
            
    model_result = pd.DataFrame({'Vector':df_name_list,'Metric':metric_list,
                               'Calibrated Estimator':best_estimator_list,
                               'Best CV Metric Score':best_score_list, 'Test Predict Metric Score': test_predict_result_list})
    return model_result

# %%
param_grid = {'max_depth': [None,30,32,35,37,38,39,40],'min_samples_split': [2,150,170,180,190,200]}
base_estimator = RandomForestClassifier(random_state=random_state_number)
rfc_result = get_performance(param_grid, base_estimator, dataframes)
rfc_result
# Out:
#             Vector    Metric  \
# 0          unigram        f1
# 1          unigram   roc_auc
# 2          unigram  accuracy
# 3   unigram_bigram        f1
# 4   unigram_bigram   roc_auc
# 5   unigram_bigram  accuracy
# 6           bigram        f1
# 7           bigram   roc_auc
# 8           bigram  accuracy
# 9   bigram_trigram        f1
# 10  bigram_trigram   roc_auc
# 11  bigram_trigram  accuracy
# 12         trigram        f1
# 13         trigram   roc_auc
# 14         trigram  accuracy
#
#                                                                                                                                                                                                                                               Calibrated Estimator  \
# 0   (DecisionTreeClassifier(max_depth=39, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=39, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 1   (DecisionTreeClassifier(max_features='sqrt', min_samples_split=190,\n                       random_state=1985925507), DecisionTreeClassifier(max_features='sqrt', min_samples_split=190,\n                       random_state=1459224502), DecisionTreeClas...
# 2   (DecisionTreeClassifier(max_features='sqrt', random_state=1985925507), DecisionTreeClassifier(max_features='sqrt', random_state=1459224502), DecisionTreeClassifier(max_features='sqrt', random_state=834170083), DecisionTreeClassifier(max_features='sqrt...
# 3   (DecisionTreeClassifier(max_depth=30, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=30, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 4   (DecisionTreeClassifier(max_depth=37, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=37, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 5   (DecisionTreeClassifier(max_depth=32, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=32, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 6   (DecisionTreeClassifier(max_depth=35, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=35, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 7   (DecisionTreeClassifier(max_depth=39, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=39, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 8   (DecisionTreeClassifier(max_depth=35, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=35, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=3...
# 9   (DecisionTreeClassifier(max_features='sqrt', min_samples_split=200,\n                       random_state=1985925507), DecisionTreeClassifier(max_features='sqrt', min_samples_split=200,\n                       random_state=1459224502), DecisionTreeClas...
# 10  (DecisionTreeClassifier(max_depth=40, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=40, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=4...
# 11  (DecisionTreeClassifier(max_features='sqrt', min_samples_split=200,\n                       random_state=1985925507), DecisionTreeClassifier(max_features='sqrt', min_samples_split=200,\n                       random_state=1459224502), DecisionTreeClas...
# 12  (DecisionTreeClassifier(max_depth=40, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=40, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=4...
# 13  (DecisionTreeClassifier(max_features='sqrt', random_state=1985925507), DecisionTreeClassifier(max_features='sqrt', random_state=1459224502), DecisionTreeClassifier(max_features='sqrt', random_state=834170083), DecisionTreeClassifier(max_features='sqrt...
# 14  (DecisionTreeClassifier(max_depth=40, max_features='sqrt',\n                       random_state=1985925507), DecisionTreeClassifier(max_depth=40, max_features='sqrt',\n                       random_state=1459224502), DecisionTreeClassifier(max_depth=4...
#
#     Best CV Metric Score  Test Predict Metric Score
# 0               0.697351                   0.503425
# 1               0.771019                   0.644342
# 2               0.707807                   0.698396
# 3               0.675793                   0.495345
# 4               0.771668                   0.637827
# 5               0.699640                   0.702674
# 6               0.519562                   0.311751
# 7               0.696543                   0.566742
# 8               0.634832                   0.693048
# 9               0.415665                   0.229508
# 10              0.695191                   0.563230
# 11              0.608625                   0.698396
# 12              0.320038                   0.218487
# 13              0.633802                   0.562110
# 14              0.572558                   0.701604

# %%
param_grid = {'n_neighbors': [5,7,9,11,13,15,17,19,21]}
base_estimator = KNeighborsClassifier()
knn_result = get_performance(param_grid, base_estimator, dataframes)
knn_result
# Out:
#             Vector    Metric                  Calibrated Estimator  \
# 0          unigram        f1  KNeighborsClassifier(n_neighbors=11)
# 1          unigram   roc_auc  KNeighborsClassifier(n_neighbors=15)
# 2          unigram  accuracy  KNeighborsClassifier(n_neighbors=11)
# 3   unigram_bigram        f1  KNeighborsClassifier(n_neighbors=13)
# 4   unigram_bigram   roc_auc  KNeighborsClassifier(n_neighbors=21)
# 5   unigram_bigram  accuracy  KNeighborsClassifier(n_neighbors=21)
# 6           bigram        f1  KNeighborsClassifier(n_neighbors=17)
# 7           bigram   roc_auc  KNeighborsClassifier(n_neighbors=13)
# 8           bigram  accuracy   KNeighborsClassifier(n_neighbors=9)
# 9   bigram_trigram        f1                KNeighborsClassifier()
# 10  bigram_trigram   roc_auc  KNeighborsClassifier(n_neighbors=17)
# 11  bigram_trigram  accuracy  KNeighborsClassifier(n_neighbors=13)
# 12         trigram        f1                KNeighborsClassifier()
# 13         trigram   roc_auc  KNeighborsClassifier(n_neighbors=15)
# 14         trigram  accuracy  KNeighborsClassifier(n_neighbors=19)
#
#     Best CV Metric Score  Test Predict Metric Score
# 0               0.632191                   0.490385
# 1               0.627194                   0.527820
# 2               0.575452                   0.546524
# 3               0.555214                   0.422764
# 4               0.587011                   0.566179
# 5               0.557740                   0.536898
# 6               0.436973                   0.488852
# 7               0.552716                   0.442016
# 8               0.545653                   0.666310
# 9               0.537134                   0.137536
# 10              0.523624                   0.490843
# 11              0.515594                   0.314439
# 12              0.415430                   0.056604
# 13              0.546795                   0.481252
# 14              0.517277                   0.329412

# %%
param_grid = {'max_depth': [None,4,6,7,8,30,32,35],'min_samples_split': [2,3,4,5,35,10,16,20]}
base_estimator = DecisionTreeClassifier(random_state=random_state_number)
dtc_result = get_performance(param_grid, base_estimator, dataframes)
dtc_result
# Out:
#             Vector    Metric  \
# 0          unigram        f1
# 1          unigram   roc_auc
# 2          unigram  accuracy
# 3   unigram_bigram        f1
# 4   unigram_bigram   roc_auc
# 5   unigram_bigram  accuracy
# 6           bigram        f1
# 7           bigram   roc_auc
# 8           bigram  accuracy
# 9   bigram_trigram        f1
# 10  bigram_trigram   roc_auc
# 11  bigram_trigram  accuracy
# 12         trigram        f1
# 13         trigram   roc_auc
# 14         trigram  accuracy
#
#                                                              Calibrated Estimator  \
# 0                                       DecisionTreeClassifier(random_state=8888)
# 1   DecisionTreeClassifier(max_depth=35, min_samples_split=20, random_state=8888)
# 2                         DecisionTreeClassifier(max_depth=35, random_state=8888)
# 3    DecisionTreeClassifier(max_depth=32, min_samples_split=4, random_state=8888)
# 4                 DecisionTreeClassifier(min_samples_split=10, random_state=8888)
# 5    DecisionTreeClassifier(max_depth=32, min_samples_split=4, random_state=8888)
# 6     DecisionTreeClassifier(max_depth=7, min_samples_split=5, random_state=8888)
# 7   DecisionTreeClassifier(max_depth=35, min_samples_split=20, random_state=8888)
# 8                  DecisionTreeClassifier(min_samples_split=3, random_state=8888)
# 9     DecisionTreeClassifier(max_depth=7, min_samples_split=5, random_state=8888)
# 10  DecisionTreeClassifier(max_depth=35, min_samples_split=20, random_state=8888)
# 11                DecisionTreeClassifier(min_samples_split=10, random_state=8888)
# 12                 DecisionTreeClassifier(min_samples_split=3, random_state=8888)
# 13  DecisionTreeClassifier(max_depth=35, min_samples_split=20, random_state=8888)
# 14                 DecisionTreeClassifier(min_samples_split=3, random_state=8888)
#
#     Best CV Metric Score  Test Predict Metric Score
# 0               0.638686                   0.446203
# 1               0.660006                   0.606195
# 2               0.640809                   0.675936
# 3               0.585977                   0.412214
# 4               0.666436                   0.597875
# 5               0.636548                   0.670588
# 6               0.174057                   0.074303
# 7               0.600764                   0.552480
# 8               0.633139                   0.688770
# 9               0.173150                   0.074303
# 10              0.600521                   0.553277
# 11              0.634839                   0.683422
# 12              0.414405                   0.210526
# 13              0.554334                   0.523670
# 14              0.571759                   0.695187

# %%
df_result = pd.concat([knn_result, 
                      dtc_result,
                      rfc_result
                      ]
                     ).reset_index(drop=True)

df_result.groupby(['Metric']).max()
# Out:
#                          Vector  Best CV Metric Score  \
# Metric
# accuracy         unigram_bigram              0.640809
# f1               unigram_bigram              0.638686
# precision_macro  unigram_bigram              0.621319
# recall_macro     unigram_bigram              0.489422
# roc_auc          unigram_bigram              0.666436
#
#                  Test Predict Metric Score
# Metric
# accuracy                          0.695187
# f1                                0.490385
# precision_macro                   0.366521
# recall_macro                      0.383834
# roc_auc                           0.606195
